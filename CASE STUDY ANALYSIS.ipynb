# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csdata = pd.read_csv('cross_sectional_data.csv')
lgdata = pd.read_csv('longitudinal_data.csv')
diabetes = pd.read_csv('Diabetes.csv')
totalgdp = pd.read_csv('GDP TOTAL.csv')
life = pd.read_csv('Life Expectancy.csv')
gdp_lcu = pd.read_csv('gdplcu.csv')
infant = pd.read_csv('Infant Mortality.csv')
literacy = pd.read_csv('literacy rate.csv')
health_exp = pd.read_csv('health expenditure.csv')
pollution = pd.read_csv('pollution.csv')

# %%
csdata.head()
# Out:
#    Unnamed: 0 iso2c                                        country  year  \
# 0           1    1A                                     Arab World  2015
# 1           2    1W                                          World  2015
# 2           3    4E    East Asia & Pacific (excluding high income)  2015
# 3           4    7E  Europe & Central Asia (excluding high income)  2015
# 4           5    8S                                     South Asia  2015
#
#    NY.GDP.PCAP.CD  SP.DYN.IMRT.IN
# 0     6545.217753       27.983485
# 1    10057.925612       31.700000
# 2     6488.381689       14.900000
# 3     7033.628566       14.900000
# 4     1542.209682       41.900000

# %%
#plot histogram of csdata log of NY.GDP.PCAP.CD	and log of SP.DYN.IMRT.IN in 2 subplots
csdata['Log_GDP'] = np.log(csdata['NY.GDP.PCAP.CD'])
csdata['Log_IMR'] = np.log(csdata['SP.DYN.IMRT.IN'])

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].hist(csdata['Log_GDP'], bins=20)
ax[0].set_title('Log of GDP per Capita')
ax[1].hist(csdata['Log_IMR'], bins=20)
ax[1].set_title('Log of Infant Mortality Rate')
plt.show()

# %%
#plot histogram of csdata NY.GDP.PCAP.CD, SP.DYN.IMRT.IN, log of NY.GDP.PCAP.CD	and log of SP.DYN.IMRT.IN in 4 subplots

fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax[0, 0].hist(csdata['NY.GDP.PCAP.CD'], bins=20)
ax[0, 0].set_title('GDP per Capita')
ax[0, 1].hist(csdata['SP.DYN.IMRT.IN'], bins=20)
ax[0, 1].set_title('Infant Mortality Rate')
ax[1, 0].hist(csdata['Log_GDP'], bins=20)
ax[1, 0].set_title('Log of GDP per Capita')
ax[1, 1].hist(csdata['Log_IMR'], bins=20)
ax[1, 1].set_title('Log of Infant Mortality Rate')
plt.show()

# %%
lgdata.head()
# Out:
#    Unnamed: 0 iso2c         country  year  NY.GDP.PCAP.CD  SP.DYN.IMRT.IN
# 0           1    GB  United Kingdom  1960     1380.306241            22.9
# 1           2    GB  United Kingdom  1961     1452.544709            22.5
# 2           3    GB  United Kingdom  1962     1513.651449            22.0
# 3           4    GB  United Kingdom  1963     1592.614477            21.4
# 4           5    GB  United Kingdom  1964     1729.399978            20.8

# %%
diabetes.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  \
# 0  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 1  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 2  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 3  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 4  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
#
#         2021
# 0   4.300000
# 1   7.381941
# 2  10.900000
# 3   3.389805
# 4   4.600000

# %%
totalgdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  1.847810e+10  1.936631e+10  2.050647e+10  2.224273e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.041165e+10  1.113592e+10  1.195171e+10  1.268581e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2014          2015          2016  \
# ...

# %%
life.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code       1960  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  64.152000
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  44.085552
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.535000
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.845152
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  38.211000
#
#         1961       1962       1963       1964       1965  ...       2014  \
# 0  64.537000  64.752000  65.132000  65.294000  65.502000  ...  75.601000
# 1  44.386697  44.752182  44.913159  45.479043  45.498338  ...  61.337917
# ...

# %%
totalgdp.shape
# Out:
# (266, 68)

# %%
#check for missing data and arrange in descending order
totalgdp.isnull().sum().sort_values(ascending=False)
# Out:
# 2023              266
# 1960              140
# 1961              139
# 1962              138
# 1963              138
#                  ...
# 2014                6
# Indicator Code      0
# Country Code        0
# Indicator Name      0
# Country Name        0
# Length: 68, dtype: int64

# %%
life.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960               14
#                  ...
# 2019                9
# 2020                9
# 2021                9
# 2022              266
# 2023              266
# Length: 68, dtype: int64

# %%
csdata.drop(columns='Unnamed: 0',inplace=True)
lgdata.drop(columns='Unnamed: 0',inplace=True)
life.drop(columns=['2022','2023'],inplace=True)
totalgdp.drop(columns=['2023'],inplace=True)
totalgdp.drop(columns=totalgdp.columns[4:44],inplace=True)

# %%
csdata.describe()
# Out:
#          year  NY.GDP.PCAP.CD  SP.DYN.IMRT.IN     Log_GDP     Log_IMR
# count   264.0      228.000000      239.000000  228.000000  239.000000
# mean   2015.0    12378.192465       24.829888    8.561541    2.759375
# std       0.0    17236.012565       21.364135    1.388048    1.045717
# min    2015.0      277.068309        1.500000    5.624264    0.405465
# 25%    2015.0     1651.362210        7.200000    7.409181    1.973985
# 50%    2015.0     5365.743424       17.400000    8.587494    2.856470
# 75%    2015.0    13665.093658       37.800000    9.522598    3.632306
# max    2015.0   101449.968168       96.000000   11.527321    4.564348

# %%
lgdata.describe()
# Out:
#               year  NY.GDP.PCAP.CD  SP.DYN.IMRT.IN
# count    56.000000       56.000000       56.000000
# mean   1987.500000    18374.365731       10.730357
# std      16.309506    15714.579026        6.105345
# min    1960.000000     1380.306241        3.500000
# 25%    1973.750000     3605.966153        5.375000
# 50%    1987.500000    14552.877306        9.000000
# 75%    2001.250000    28516.644883       16.150000
# max    2015.000000    49949.154881       22.900000

# %%
lgdata['iso2c'].unique()
# Out:
# array(['GB'], dtype=object)

# %%
csdata['country'].nunique()
# Out:
# 264

# %%
csdata[csdata['country']=='United Kingdom']
# Out:
#    iso2c         country  year  NY.GDP.PCAP.CD  SP.DYN.IMRT.IN    Log_GDP  \
# 73    GB  United Kingdom  2015    43875.969614             3.5  10.689122
#
#      Log_IMR
# 73  1.252763

# %%
lgdata[lgdata['year']==2015]
# Out:
#    iso2c         country  year  NY.GDP.PCAP.CD  SP.DYN.IMRT.IN
# 55    GB  United Kingdom  2015    43875.969614             3.5

# %%
#plot between NY.GDP.PCAP.CD and SP.DYN.IMRT.IN for lgdata
plt.scatter(lgdata[lgdata['iso2c']=='GB']['NY.GDP.PCAP.CD'],lgdata[lgdata['iso2c']=='GB']['SP.DYN.IMRT.IN'])
plt.xlabel('Log of GDP per capita (U.S.$)')
plt.xscale('log')
plt.ylabel('Infant Mortality Rate')
plt.title('GDP per capita vs Infant Mortality Rate in UK')
plt.show()

# %%
#plot between NY.GDP.PCAP.CD and SP.DYN.IMRT.IN for csdata for all countries
plt.scatter(csdata['NY.GDP.PCAP.CD'],csdata['SP.DYN.IMRT.IN'])
plt.xscale('log') 
plt.xlabel('GDP per capita')
plt.ylabel('Infant Mortality Rate')
plt.title('GDP per capita vs Infant Mortality Rate')
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the size of the plot
plt.scatter(csdata['NY.GDP.PCAP.CD'], csdata['SP.DYN.IMRT.IN']) 
plt.xscale('log')  # Logarithmic scale for x-axis
plt.xlabel('Log of GDP Per Capita (U.S.%)')
plt.ylabel('Infant Mortality /1000')
plt.title('GDP Per Capita vs Infant Mortality Rate')
 # Enable grid for better readability
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns

# First subplot
axs[0].scatter(csdata['NY.GDP.PCAP.CD'], csdata['SP.DYN.IMRT.IN'])
axs[0].set_xscale('log')  # Logarithmic scale for x-axis
axs[0].set_xlabel('Log of GDP Per Capita (U.S.$)')
axs[0].set_ylabel('Infant Mortality /1000')
axs[0].set_title('(a) GDP Per Capita vs Infant Mortality Rate')

# Second subplot
axs[1].scatter(lgdata[lgdata['iso2c'] == 'GB']['NY.GDP.PCAP.CD'], lgdata[lgdata['iso2c'] == 'GB']['SP.DYN.IMRT.IN'])
axs[1].set_xscale('log')  # Logarithmic scale for x-axis
axs[1].set_xlabel('Log of GDP per capita (U.S.$)')
axs[1].set_ylabel('Infant Mortality Rate')
axs[1].set_title('(b) GDP per capita vs Infant Mortality Rate in UK')

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
lgdata.head()
# Out:
#   iso2c         country  year  NY.GDP.PCAP.CD  SP.DYN.IMRT.IN
# 0    GB  United Kingdom  1960     1380.306241            22.9
# 1    GB  United Kingdom  1961     1452.544709            22.5
# 2    GB  United Kingdom  1962     1513.651449            22.0
# 3    GB  United Kingdom  1963     1592.614477            21.4
# 4    GB  United Kingdom  1964     1729.399978            20.8

# %%
lgdata['year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015], dtype=int64)

# %%
import matplotlib.pyplot as plt

# Assuming 'data' DataFrame is correctly defined with 'Life_Expectancy' and 'Log_GDP' calculated correctly
plt.figure(figsize=(10, 6))
plt.scatter(data['Log_GDP'], data['Life_Expectancy'], color='blue', alpha=0.6)
plt.title('Relationship between Life Expectancy and Log GDP')
plt.xlabel('Log of GDP')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# %%
diabetes.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  \
# 0  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 1  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 2  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 3  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 4  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
#
#         2021
# 0   4.300000
# 1   7.381941
# 2  10.900000
# 3   3.389805
# 4   4.600000

# %%
#diabetes data with country name United Kingdom
diabetes[diabetes['Country Name']=='United Kingdom']
# Out:
#       Country Name Country Code  \
# 81  United Kingdom          GBR
#
#                                        Indicator Name  Indicator Code  2021
# 81  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS   6.3

# %%
# plot for life[life['Country Name']=='United Kingdom'] for x as all the years (1960-2022) and y as the values in the columns 1960-2022

plt.plot(life[life['Country Name']=='United Kingdom'].columns[4:],life[life['Country Name']=='United Kingdom'].iloc[0,4:])
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy in United Kingdom')
plt.show()

# %%
lgdata.head()
# Out:
#   iso2c         country  year  NY.GDP.PCAP.CD  SP.DYN.IMRT.IN
# 0    GB  United Kingdom  1960     1380.306241            22.9
# 1    GB  United Kingdom  1961     1452.544709            22.5
# 2    GB  United Kingdom  1962     1513.651449            22.0
# 3    GB  United Kingdom  1963     1592.614477            21.4
# 4    GB  United Kingdom  1964     1729.399978            20.8

# %%
life_years = life.columns[4:]  # Adjust based on your DataFrame structure
life_expectancy_values = life[life['Country Name']=='United Kingdom'].iloc[0,4:].values

# %%
# Assuming lgdata, life_years, and life_expectancy_values are your data variables correctly set up
plt.figure(figsize=(22, 8))  # Adjust the figure size to better fit a horizontal layout

# First subplot for GDP
plt.subplot(1, 3, 1)  # (rows, columns, panel number)
plt.plot(lgdata['year'], lgdata['NY.GDP.PCAP.CD'], marker='o', linestyle='-')
plt.title('Trend of GDP in the UK')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.grid(True)

# Second subplot for Infant Mortality
plt.subplot(1, 3, 2)
plt.plot(lgdata['year'], lgdata['SP.DYN.IMRT.IN'], marker='o', linestyle='-')
plt.title('Trend of Infant Mortality in the UK')
plt.xlabel('Year')
plt.ylabel('Infant Mortality Rate')
plt.grid(True)

# Third subplot for Life Expectancy
plt.subplot(1, 3, 3)
plt.plot(life_years, life_expectancy_values, marker='o', linestyle='-')
plt.xticks(life_years[::10])
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy in UK')
plt.grid(True)

plt.tight_layout()  # Adjusts plot parameters to give specified padding
plt.show()

# %%
life.fillna(method='ffill', inplace=True)  # Forward fill missing values
# Out:
# C:\Users\rosha\AppData\Local\Temp\ipykernel_35448\2838826510.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   life.fillna(method='ffill', inplace=True)  # Forward fill missing values

# %%
csdata.columns
# Out:
# Index(['iso2c', 'country', 'year', 'NY.GDP.PCAP.CD', 'SP.DYN.IMRT.IN',
#        'Log_GDP', 'Log_IMR'],
#       dtype='object')

# %%
totalgdp_long = totalgdp.melt(id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
                              var_name="Year",
                              value_name="GDP")

totalgdp_long['Year'] = totalgdp_long['Year'].astype(int)

# Define the countries of interest
countries_of_interest = ['United States', 'Canada', 'United Arab Emirates', 'India', 'China', 'United Kingdom', 'Germany', 'France', 'Italy', 'Spain']

# Filter the data for these countries
filtered_gdp_data1 = totalgdp_long[totalgdp_long['Country Name'].isin(countries_of_interest)]

# %%
gdp_lcu_long = gdp_lcu.melt(id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
                              var_name="Year",
                              value_name="GDP")

gdp_lcu_long['Year'] = gdp_lcu_long['Year'].astype(int)

countries_of_interest = ['United States', 'Canada', 'India', 'China', 'United Kingdom']

filtered_gdp_data2 = gdp_lcu_long[gdp_lcu_long['Country Name'].isin(countries_of_interest)]

# %%
infant_long = infant.melt(id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
                                var_name="Year",
                                value_name="Infant Mortality Rate")

infant_long['Year'] = infant_long['Year'].astype(int)

countries_of_interest = ['United States', 'Canada', 'India', 'China', 'United Kingdom']

filtered_infant_data = infant_long[infant_long['Country Name'].isin(countries_of_interest)]

# %%
# Setting up the figure and axes
plt.figure(figsize=(15, 10))

# Plotting each country's GDP trend
for country in countries_of_interest:
    country_data = filtered_gdp_data1[filtered_gdp_data1['Country Name'] == country]
    plt.plot(country_data['Year'], country_data['GDP'], label=country, marker='o')

plt.title('GDP (US$) Trends Over the Years for Selected Countries')
plt.xlabel('Year')
plt.ylabel('GDP in USD')
plt.legend(title='Country')
plt.yscale('log')  # Logarithmic scale for better readability
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 10))

# Plotting each country's GDP trend
for country in countries_of_interest:
    country_data = filtered_gdp_data2[filtered_gdp_data2['Country Name'] == country]
    plt.plot(country_data['Year'], country_data['GDP'], label=country, marker='o')

plt.title('GDP (current LCU) Trends Over the Years for Selected Countries')
plt.xlabel('Year')
plt.ylabel('GDP in LCU')
plt.legend(title='Country')
plt.yscale('log')  # Logarithmic scale for y-axis
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 10))

# Plotting each country's GDP trend
for country in countries_of_interest:
    country_data = filtered_infant_data[filtered_infant_data['Country Name'] == country]
    plt.plot(country_data['Year'], country_data['Infant Mortality Rate'], label=country, marker='o')

plt.title('Infant Mortality Trends Over the Years for Selected Countries')
plt.xlabel('Year')
plt.ylabel('Infant Mortality Rate')
plt.legend(title='Country')
plt.yscale('log')  # Logarithmic scale for y-axis
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(1, 2, figsize=(20, 8))  # 1 row, 2 columns

# Plotting GDP trends for selected countries
for country in countries_of_interest:
    country_data = filtered_gdp_data2[filtered_gdp_data2['Country Name'] == country]
    axs[0].plot(country_data['Year'], country_data['GDP'], label=country, marker='o')

axs[0].set_title('GDP (current LCU) Trends Over the Years for Selected Countries')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('GDP in LCU')
axs[0].legend(title='Country')
axs[0].set_yscale('log')  # Logarithmic scale for y-axis
axs[0].grid(True)

# Plotting infant mortality trends for selected countries
for country in countries_of_interest:
    country_data = filtered_infant_data[filtered_infant_data['Country Name'] == country]
    axs[1].plot(country_data['Year'], country_data['Infant Mortality Rate'], label=country, marker='o')

axs[1].set_title('Infant Mortality Trends Over the Years for Selected Countries')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Infant Mortality Rate')
axs[1].legend(title='Country')
axs[1].set_yscale('log')  # Logarithmic scale for y-axis
axs[1].grid(True)

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
#plot for literacy rate from literacy_long for all countries
plt.plot(literacy_long[literacy_long['Country Name']=='United Kingdom']['Year'],literacy_long[literacy_long['Country Name']=='United Kingdom']['Literacy Rate'])
plt.xlabel('Years')
plt.ylabel('Literacy Rate')
plt.title('Literacy Rate in United Kingdom')
plt.show()

# %%
# Define the years and countries of interest
years_of_interest = [2000, 2010, 2020]
countries_of_interest = ['United States', 'Canada', 'India', 'China', 'United Kingdom']

# Filter the GDP data for specified years and countries
gdp_filtered = totalgdp_long[
    (totalgdp_long['Year'].isin(years_of_interest)) & 
    (totalgdp_long['Country Name'].isin(countries_of_interest))
]

# Filter the Infant Mortality data similarly
infant_filtered = infant_long[
    (infant_long['Year'].isin(years_of_interest)) & 
    (infant_long['Country Name'].isin(countries_of_interest))
]

# %%
gdp_filtered['Log_GDP'] = np.log(gdp_filtered['GDP'])

gdp_filtered = gdp_filtered.sort_values('Country Name')

print(gdp_filtered[['Year','Country Name', 'Log_GDP','GDP']])
# Out:
#       Year    Country Name    Log_GDP           GDP
# 35    2000          Canada  27.336345  7.447730e+11
# 2695  2010          Canada  28.111804  1.617340e+12
# 5355  2020          Canada  28.135233  1.655680e+12
# 40    2000           China  27.822740  1.211330e+12
# 2700  2010           China  29.437208  6.087190e+12
# 5360  2020           China  30.318032  1.468770e+13
# 109   2000           India  26.872578  4.683950e+11
# 2769  2010           India  28.147204  1.675620e+12
# 5429  2020           India  28.613699  2.671600e+12
# 81    2000  United Kingdom  28.141165  1.665530e+12
# 2741  2010  United Kingdom  28.541487  2.485480e+12
# 5401  2020  United Kingdom  28.623461  2.697810e+12
# 251   2000   United States  29.958387  1.025090e+13
# 2911  2010   United States  30.342333  1.504900e+13
# 5571  2020   United States  30.678420  2.106050e+13
# C:\Users\rosha\AppData\Local\Temp\ipykernel_35448\2919560150.py:1: SettingWithCopyWarning:
# ...

# %%
gdp_2000 = gdp_filtered[gdp_filtered['Year'] == 2000].set_index('Country Name')['GDP']
gdp_2020 = gdp_filtered[gdp_filtered['Year'] == 2020].set_index('Country Name')['GDP']

percentage_increase = ((gdp_2020 - gdp_2000) / gdp_2000) * 100

print("Percentage Increase of GDP from 2000 to 2020:")
print(percentage_increase) #old
# Out:
# Percentage Increase of GDP from 2000 to 2020:
# Country Name
# Canada             122.306663
# China             1112.526727
# India              470.373296
# United Kingdom      61.979070
# United States      105.450253
# Name: GDP, dtype: float64

# %%
gdp_2000 = gdp_filtered[gdp_filtered['Year'] == 2000].set_index('Country Name')['GDP']
gdp_2020 = gdp_filtered[gdp_filtered['Year'] == 2020].set_index('Country Name')['GDP']

percentage_increase = ((gdp_2020 - gdp_2000) / gdp_2000) * 100

print("Percentage Increase of GDP from 2000 to 2020:")
print(percentage_increase) #use this
# Out:
# Percentage Increase of GDP from 2000 to 2020:
# Country Name
# Canada             122.306663
# China             1112.526727
# India              470.373296
# United Kingdom      61.979070
# United States      105.450253
# Name: GDP, dtype: float64

# %%
infant_filtered['Log_Infant_Mortality'] = np.log(infant_filtered['Infant Mortality Rate'])

infant_filtered = infant_filtered.sort_values('Country Name')

print(infant_filtered[['Year','Country Name', 'Log_Infant_Mortality','Infant Mortality Rate']])
# Out:
#        Year    Country Name  Log_Infant_Mortality  Infant Mortality Rate
# 10675  2000          Canada              1.667707                    5.3
# 13335  2010          Canada              1.609438                    5.0
# 15995  2020          Canada              1.504077                    4.5
# 10680  2000           China              3.401197                   30.0
# 13340  2010           China              2.525729                   12.5
# 16000  2020           China              1.704748                    5.5
# 10749  2000           India              4.200205                   66.7
# 13409  2010           India              3.808882                   45.1
# 16069  2020           India              3.288402                   26.8
# 10721  2000  United Kingdom              1.722767                    5.6
# 13381  2010  United Kingdom              1.481605                    4.4
# 16041  2020  United Kingdom              1.308333                    3.7
# ...

# %%
# Filter data for 2000 and 2020
imr_2000 = infant_filtered[infant_filtered['Year'] == 2000].set_index('Country Name')['Infant Mortality Rate']
imr_2020 = infant_filtered[infant_filtered['Year'] == 2020].set_index('Country Name')['Infant Mortality Rate']

# Calculate percentage decrease
percentage_decrease = ((imr_2000 - imr_2020) / imr_2000) * 100

# Display the result
print("Percentage Decrease of Infant Mortality Rate from 2000 to 2020:")
print(percentage_decrease)
# Out:
# Percentage Decrease of Infant Mortality Rate from 2000 to 2020:
# Country Name
# Canada            15.094340
# China             81.666667
# India             59.820090
# United Kingdom    33.928571
# United States     23.943662
# Name: Infant Mortality Rate, dtype: float64

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# Merge the datasets on 'Country Name' and 'Year'
merged_data = pd.merge(gdp_filtered, infant_filtered, on=['Country Name', 'Year'])

# Check the merged data
print(merged_data.head())
# Out:
#   Country Name Country Code_x   Indicator Name_x Indicator Code_x  Year  \
# 0       Canada            CAN  GDP (current US$)   NY.GDP.MKTP.CD  2000
# 1       Canada            CAN  GDP (current US$)   NY.GDP.MKTP.CD  2010
# 2       Canada            CAN  GDP (current US$)   NY.GDP.MKTP.CD  2020
# 3        China            CHN  GDP (current US$)   NY.GDP.MKTP.CD  2000
# 4        China            CHN  GDP (current US$)   NY.GDP.MKTP.CD  2010
#
#             GDP    Log_GDP Country Code_y  \
# 0  7.447730e+11  27.336345            CAN
# 1  1.617340e+12  28.111804            CAN
# 2  1.655680e+12  28.135233            CAN
# 3  1.211330e+12  27.822740            CHN
# 4  6.087190e+12  29.437208            CHN
#
#                                  Indicator Name_y Indicator Code_y  \
# 0  Mortality rate, infant (per 1,000 live births)   SP.DYN.IMRT.IN
# 1  Mortality rate, infant (per 1,000 live births)   SP.DYN.IMRT.IN
# 2  Mortality rate, infant (per 1,000 live births)   SP.DYN.IMRT.IN
# ...

# %%
import statsmodels.api as sm

# Define the independent variables (add a constant term for the intercept)
X = sm.add_constant(merged_data['Log_GDP'])

# Define the dependent variable
Y = merged_data['Infant Mortality Rate']

# Fit the OLS model
model = sm.OLS(Y, X).fit()

# Print the summary of the regression model
print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant Mortality Rate   R-squared:                       0.258
# Model:                               OLS   Adj. R-squared:                  0.201
# Method:                    Least Squares   F-statistic:                     4.518
# Date:                   Thu, 09 May 2024   Prob (F-statistic):             0.0533
# Time:                           09:05:04   Log-Likelihood:                -62.463
# No. Observations:                     15   AIC:                             128.9
# Df Residuals:                         13   BIC:                             130.3
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        252.2962    111.451      2.264      0.041      11.521     493.071
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot with regression line
sns.regplot(x='Log_GDP', y='Infant Mortality Rate', data=merged_data)
plt.title('Log GDP vs. Infant Mortality Rate')
plt.xlabel('Log of GDP')
plt.ylabel('Infant Mortality Rate')
plt.show()

# %%
gdp_lcu_long['Log_GDP'] = np.log(gdp_lcu_long['GDP'])
infant_long['Log_Infant_Mortality'] = np.log(infant_long['Infant Mortality Rate'])

# %%
# Merge the datasets on 'Country Name' and 'Year'
merged_data = pd.merge(gdp_lcu_long, infant_long, on=['Country Name', 'Year'])

# Check the merged data
print(merged_data.head())
# Out:
#                   Country Name Country Code_x   Indicator Name_x  \
# 0                        Aruba            ABW  GDP (current LCU)
# 1  Africa Eastern and Southern            AFE  GDP (current LCU)
# 2                  Afghanistan            AFG  GDP (current LCU)
# 3   Africa Western and Central            AFW  GDP (current LCU)
# 4                       Angola            AGO  GDP (current LCU)
#
#   Indicator Code_x  Year           GDP    Log_GDP Country Code_y  \
# 0   NY.GDP.MKTP.CN  1960           NaN        NaN            ABW
# 1   NY.GDP.MKTP.CN  1960           NaN        NaN            AFE
# 2   NY.GDP.MKTP.CN  1960  2.420000e+10  23.909619            AFG
# 3   NY.GDP.MKTP.CN  1960           NaN        NaN            AFW
# 4   NY.GDP.MKTP.CN  1960           NaN        NaN            AGO
#
#                                  Indicator Name_y Indicator Code_y  \
# 0  Mortality rate, infant (per 1,000 live births)   SP.DYN.IMRT.IN
# ...

# %%
merged_data = merged_data.dropna()

# %%
merged_data.head()
# Out:
#     Country Name Country Code_x   Indicator Name_x Indicator Code_x  Year  \
# 13     Australia            AUS  GDP (current LCU)   NY.GDP.MKTP.CN  1960
# 14       Austria            AUT  GDP (current LCU)   NY.GDP.MKTP.CN  1960
# 17       Belgium            BEL  GDP (current LCU)   NY.GDP.MKTP.CN  1960
# 18         Benin            BEN  GDP (current LCU)   NY.GDP.MKTP.CN  1960
# 19  Burkina Faso            BFA  GDP (current LCU)   NY.GDP.MKTP.CN  1960
#
#              GDP    Log_GDP Country Code_y  \
# 13  1.661300e+10  23.533451            AUS
# 14  1.245685e+10  23.245537            AUT
# 17  1.445061e+10  23.394002            BEL
# 18  5.546205e+10  24.738965            BEN
# 19  8.102296e+10  25.117998            BFA
#
#                                   Indicator Name_y Indicator Code_y  \
# 13  Mortality rate, infant (per 1,000 live births)   SP.DYN.IMRT.IN
# 14  Mortality rate, infant (per 1,000 live births)   SP.DYN.IMRT.IN
# ...

# %%
merged_data.shape
# Out:
# (9524, 12)

# %%
merged_data.drop(columns=['Country Code_x','Indicator Name_x','Indicator Code_x','Country Code_y','Indicator Name_y','Indicator Code_y'],inplace=True)

# %%
merged_data.head()
# Out:
#     Country Name  Year           GDP    Log_GDP  Infant Mortality Rate  \
# 13     Australia  1960  1.661300e+10  23.533451                   20.3
# 14       Austria  1960  1.245685e+10  23.245537                   37.3
# 17       Belgium  1960  1.445061e+10  23.394002                   29.4
# 18         Benin  1960  5.546205e+10  24.738965                  183.9
# 19  Burkina Faso  1960  8.102296e+10  25.117998                  156.8
#
#     Log_Infant_Mortality
# 13              3.010621
# 14              3.618993
# 17              3.380995
# 18              5.214392
# 19              5.054971

# %%
import statsmodels.api as sm

# Define the independent variables (add a constant term for the intercept)
X = sm.add_constant(merged_data['Log_GDP'])

# Define the dependent variable
Y = merged_data['Log_Infant_Mortality']

# Fit the OLS model
model = sm.OLS(Y, X).fit()

# Print the summary of the regression model
print(model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Log_Infant_Mortality   R-squared:                       0.065
# Model:                              OLS   Adj. R-squared:                  0.065
# Method:                   Least Squares   F-statistic:                     659.2
# Date:                  Thu, 09 May 2024   Prob (F-statistic):          1.25e-140
# Time:                          09:05:05   Log-Likelihood:                -14278.
# No. Observations:                  9524   AIC:                         2.856e+04
# Df Residuals:                      9522   BIC:                         2.857e+04
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7190      0.056     84.972      0.000       4.610       4.828
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot with regression line
sns.regplot(x='Log_GDP', y='Log_Infant_Mortality', data=merged_data)
plt.title('Log GDP vs. Log Infant Mortality Rate')
plt.xlabel('Log of GDP')
plt.ylabel('Log of Infant Mortality Rate')
plt.show()

# %%
import statsmodels.api as sm

# Define the independent variables (add a constant term for the intercept)
X = sm.add_constant(merged_data['Log_GDP'])

# Define the dependent variable
Y = merged_data['Infant Mortality Rate']

# Fit the OLS model
model = sm.OLS(Y, X).fit()

# Print the summary of the regression model
print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant Mortality Rate   R-squared:                       0.068
# Model:                               OLS   Adj. R-squared:                  0.068
# Method:                    Least Squares   F-statistic:                     695.3
# Date:                   Thu, 09 May 2024   Prob (F-statistic):          6.00e-148
# Time:                           09:05:06   Log-Likelihood:                -48917.
# No. Observations:                   9524   AIC:                         9.784e+04
# Df Residuals:                       9522   BIC:                         9.785e+04
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        100.7741      2.109     47.776      0.000      96.639     104.909
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot with regression line
sns.regplot(x='Log_GDP', y='Infant Mortality Rate', data=merged_data)
plt.title('Log GDP vs. Infant Mortality Rate')
plt.xlabel('Log of GDP')
plt.ylabel('Infant Mortality Rate')
plt.show()

# %%
literacy_long = literacy.melt(id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
                              var_name="Year",
                              value_name="Literacy Rate")

literacy_long['Year'] = literacy_long['Year'].astype(int)

# %%
csdata.head()
# Out:
#   iso2c                                        country  year  NY.GDP.PCAP.CD  \
# 0    1A                                     Arab World  2015     6545.217753
# 1    1W                                          World  2015    10057.925612
# 2    4E    East Asia & Pacific (excluding high income)  2015     6488.381689
# 3    7E  Europe & Central Asia (excluding high income)  2015     7033.628566
# 4    8S                                     South Asia  2015     1542.209682
#
#    SP.DYN.IMRT.IN   Log_GDP   Log_IMR
# 0       27.983485  8.786490  3.331615
# 1       31.700000  9.216116  3.456317
# 2       14.900000  8.777768  2.701361
# 3       14.900000  8.858458  2.701361
# 4       41.900000  7.340972  3.735286

# %%
literacy_long['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
diabetes.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  \
# 0  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 1  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 2  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 3  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 4  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
#
#         2021
# 0   4.300000
# 1   7.381941
# 2  10.900000
# 3   3.389805
# 4   4.600000

# %%
#plot for diabetes data for all countries
plt.plot(diabetes[])
plt.xlabel('Years')
plt.ylabel('Diabetes Prevalence')
plt.title('Diabetes Prevalence in United Kingdom')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rosha\anaconda3\envs\tester\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Diabetes Prevalence'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[154], line 2
# ...

# %%
#plot for Literacy Rate from literacy_long for UK

uk_data = literacy_long[literacy_long['Country Name'] == 'United States']




plt.figure(figsize=(10, 6))
plt.plot(uk_data['Year'], uk_data['Literacy Rate'], marker='o')
plt.title('Literacy Rate in the United Kingdom')
plt.xlabel('Year')
plt.ylabel('Literacy Rate (%)')
plt.grid(True)
plt.show()

# %%
literacy_long.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  Year  \
# 0  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS  2000
# 1  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS  2000
# 2  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS  2000
# 3  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS  2000
# 4  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS  2000
#
#    Literacy Rate
# 0      97.291252
# 1      62.495178
# 2            NaN
# 3      47.057159
# 4            NaN

# %%
health_exp_long = health_exp.melt(id_vars=["Country Name", "Country Code"],
                                var_name="Year",
                                value_name="Health Expenditure")

health_exp_long['Year'] = health_exp_long['Year'].astype(int)

# %%
pollution_long = pollution.melt(id_vars=["Country Name", "Country Code"],
                                var_name="Year",
                                value_name="Pollution")

pollution_long['Year'] = pollution_long['Year'].astype(int)

# %%
life_exp_long = life.melt(id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
                                var_name="Year",
                                value_name="Life Expectancy")

life_exp_long['Year'] = life_exp_long['Year'].astype(int)

# %%
gdp_lcu_long.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current LCU)
# 1  Africa Eastern and Southern          AFE  GDP (current LCU)
# 2                  Afghanistan          AFG  GDP (current LCU)
# 3   Africa Western and Central          AFW  GDP (current LCU)
# 4                       Angola          AGO  GDP (current LCU)
#
#    Indicator Code  Year           GDP    Log_GDP
# 0  NY.GDP.MKTP.CN  1960           NaN        NaN
# 1  NY.GDP.MKTP.CN  1960           NaN        NaN
# 2  NY.GDP.MKTP.CN  1960  2.420000e+10  23.909619
# 3  NY.GDP.MKTP.CN  1960           NaN        NaN
# 4  NY.GDP.MKTP.CN  1960           NaN        NaN

# %%
gdp_lcu_long.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)
health_exp_long.drop(columns=['Country Code'],inplace=True)
literacy_long.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)
pollution_long.drop(columns=['Country Code'],inplace=True)
life_exp_long.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)
infant_long.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)

# %%
grossman_data = pd.merge(literacy_long, health_exp_long, on=['Country Name', 'Year'], how='inner')
grossman_data = pd.merge(grossman_data, pollution_long, on=['Country Name', 'Year'], how='inner')
grossman_data = pd.merge(grossman_data, gdp_lcu_long, on=['Country Name', 'Year'], how='inner')
grossman_data = pd.merge(grossman_data, life_exp_long, on=['Country Name', 'Year'], how='inner')
grossman_data = pd.merge(grossman_data, infant_long, on=['Country Name', 'Year'], how='inner')

# %%
grossman_data.head()
# Out:
#                   Country Name  Year  Literacy Rate  Health Expenditure  \
# 0                        Aruba  2000      97.291252                 NaN
# 1  Africa Eastern and Southern  2000      62.495178           43.717514
# 2                  Afghanistan  2000            NaN                 NaN
# 3   Africa Western and Central  2000      47.057159           20.182081
# 4                       Angola  2000            NaN           13.000087
#
#       Pollution           GDP    Log_GDP  Life Expectancy  \
# 0           NaN  3.353480e+09  21.933264        73.569000
# 1  936733.64230           NaN        NaN        51.964481
# 2   14205.32527           NaN        NaN        55.298000
# 3  593150.73460           NaN        NaN        50.221954
# 4   57982.70087  9.166610e+10  25.241418        46.024000
#
#    Infant Mortality Rate  Log_Infant_Mortality
# 0                    NaN                   NaN
# 1              85.831726              4.452389
# ...

# %%
grossman_data['Log Literacy'] = np.log(grossman_data['Literacy Rate'])
grossman_data['Log Health Expenditure'] = np.log(grossman_data['Health Expenditure'])
grossman_data['Log Pollution'] = np.log(grossman_data['Pollution'])
grossman_data['Log Life Exp'] = np.log(grossman_data['Life Expectancy'])
grossman_data['Log GDP'] = np.log(grossman_data['GDP'])
grossman_data['Log Infant Mortality'] = np.log(grossman_data['Infant Mortality Rate'])

# %%
grossman_data.drop(columns = ['Log_GDP', 'Log_Infant_Mortality'],inplace = True)

# %%
grossman_data.isna().sum()
# Out:
# Country Name                 0
# Year                         0
# Literacy Rate             4229
# Health Expenditure         904
# Pollution                  833
# GDP                       1257
# Life Expectancy              0
# Infant Mortality Rate      484
# Log Literacy              4229
# Log Health Expenditure     904
# Log Pollution              833
# Log Life Exp                 0
# Log GDP                   1257
# Log Infant Mortality       484
# dtype: int64

# %%
grossman_data.set_index('Year', inplace=True)

# %%
grossman_data['Health Expenditure'] = grossman_data['Health Expenditure'].interpolate(method='linear')
grossman_data['Pollution'] = grossman_data['Pollution'].interpolate(method='linear')
grossman_data['Literacy Rate'] = grossman_data['Literacy Rate'].interpolate(method='linear')
grossman_data['Life Expectancy'] = grossman_data['Life Expectancy'].interpolate(method='linear')
grossman_data['GDP'] = grossman_data['GDP'].interpolate(method='linear')
grossman_data['Infant Mortality Rate'] = grossman_data['Infant Mortality Rate'].interpolate(method='linear')


grossman_data.isna().sum()
# Out:
# Country Name                 0
# Literacy Rate                0
# Health Expenditure           1
# Pollution                    1
# GDP                          0
# Life Expectancy              0
# Infant Mortality Rate        1
# Log Literacy              4229
# Log Health Expenditure     904
# Log Pollution              833
# Log Life Exp                 0
# Log GDP                   1257
# Log Infant Mortality       484
# dtype: int64

# %%
grossman_data.reset_index(inplace=True)

# %%
grossman_data.head()
# Out:
#    Year                 Country Name  Literacy Rate  Health Expenditure  \
# 0  2000                        Aruba      97.291252                 NaN
# 1  2000  Africa Eastern and Southern      62.495178           43.717514
# 2  2000                  Afghanistan      54.776169           31.949798
# 3  2000   Africa Western and Central      47.057159           20.182081
# 4  2000                       Angola      51.494444           13.000087
#
#       Pollution           GDP  Life Expectancy  Infant Mortality Rate  \
# 0           NaN  3.353480e+09        73.569000                    NaN
# 1  936733.64230  2.543164e+10        51.964481              85.831726
# 2   14205.32527  4.750979e+10        55.298000              90.600000
# 3  593150.73460  6.958794e+10        50.221954              99.140044
# 4   57982.70087  9.166610e+10        46.024000             121.900000
#
#    Log Literacy  Log Health Expenditure  Log Pollution  Log Life Exp  \
# ...

# %%
grossman_data.columns
# Out:
# Index(['Year', 'Country Name', 'Literacy Rate', 'Health Expenditure',
#        'Pollution', 'GDP', 'Life Expectancy', 'Infant Mortality Rate',
#        'Log Literacy', 'Log Health Expenditure', 'Log Pollution',
#        'Log Life Exp', 'Log GDP', 'Log Infant Mortality'],
#       dtype='object')

# %%
grossman_data.rename(columns = {'Literacy Rate' : 'Literacy_Rate', 'Health Expenditure' : 'Health_Expenditure', 'Life Expectancy' : 'Life_Expectancy','Log Health Expenditure':'Log_Health_Expenditure', 'Log Pollution' : 'Log_Pollution' , 'Log GDP' : 'Log_GDP' , 'Log Infant Mortality' : 'Log_Infant_Mortality'})
# Out:
#       Year                 Country Name  Literacy_Rate  Health_Expenditure  \
# 0     2000                        Aruba      97.291252                 NaN
# 1     2000  Africa Eastern and Southern      62.495178           43.717514
# 2     2000                  Afghanistan      54.776169           31.949798
# 3     2000   Africa Western and Central      47.057159           20.182081
# 4     2000                       Angola      51.494444           13.000087
# ...    ...                          ...            ...                 ...
# 5847  2021                       Kosovo      96.067118         6914.905273
# 5848  2021                  Yemen, Rep.      93.034238         6914.905273
# 5849  2021                 South Africa      90.001358         6914.905273
# 5850  2021                       Zambia      90.001358         6914.905273
# 5851  2021                     Zimbabwe      90.001358         6914.905273
#
# ...

# %%
data = grossman_data.copy()

# %%
data['Log_GDP'] = np.where(data['GDP'] > 0, np.log(data['GDP']), np.nan)
data['Log_Health_Expenditure'] = np.where(data['Health Expenditure'] > 0, np.log(data['Health Expenditure']), np.nan)
data['Log_Pollution'] = np.where(data['Pollution'] > 0, np.log(data['Pollution']), np.nan)

# %%
print(data.columns)
# Out:
# Index(['Year', 'Country Name', 'Literacy Rate', 'Health Expenditure',
#        'Pollution', 'GDP', 'Life Expectancy', 'Infant Mortality Rate',
#        'Log Literacy', 'Log Health Expenditure', 'Log Pollution',
#        'Log Life Exp', 'Log GDP', 'Log Infant Mortality', 'Log_GDP',
#        'Log_Health_Expenditure', 'Log_Pollution'],
#       dtype='object')

# %%
data.dropna(subset=['Life Expectancy', 'Log_GDP', 'Log_Health_Expenditure', 'Literacy Rate', 'Log_Pollution'], inplace=True)

# %%
data.head()
# Out:
#    Year                 Country Name  Literacy Rate  Health Expenditure  \
# 1  2000  Africa Eastern and Southern      62.495178           43.717514
# 2  2000                  Afghanistan      54.776169           31.949798
# 3  2000   Africa Western and Central      47.057159           20.182081
# 4  2000                       Angola      51.494444           13.000087
# 5  2000                      Albania      55.931728           65.149994
#
#        Pollution           GDP  Life Expectancy  Infant Mortality Rate  \
# 1  936733.642300  2.543164e+10        51.964481              85.831726
# 2   14205.325270  4.750979e+10        55.298000              90.600000
# 3  593150.734600  6.958794e+10        50.221954              99.140044
# 4   57982.700870  9.166610e+10        46.024000             121.900000
# 5    8163.977582  5.011990e+11        75.404000              24.100000
#
#    Log Literacy  Log Health Expenditure  Log Pollution  Log Life Exp  \
# ...

# %%
data.shape
# Out:
# (5851, 17)

# %%
#rename Life Expectancy to Life_Expectancy and Literacy Rate to Literacy_Rate
data.rename(columns={'Life Expectancy':'Life_Expectancy','Literacy Rate':'Literacy_Rate'},inplace=True)

# %%
import statsmodels.formula.api as smf

# Now try to fit the model
model = smf.ols('Life_Expectancy ~ Log_GDP + Log_Health_Expenditure + Literacy_Rate + Log_Pollution', data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       0.490
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     1405.
# Date:                Thu, 09 May 2024   Prob (F-statistic):               0.00
# Time:                        09:05:25   Log-Likelihood:                -18876.
# No. Observations:                5851   AIC:                         3.776e+04
# Df Residuals:                    5846   BIC:                         3.780e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 48.3114      0.745     64.879      0.000      46.852      49.771
# ...

# %%
data.shape
# Out:
# (5851, 17)

# %%
data['Country Name'].nunique()
# Out:
# 266

# %%
data.columns
# Out:
# Index(['Year', 'Country Name', 'Literacy_Rate', 'Health Expenditure',
#        'Pollution', 'GDP', 'Life_Expectancy', 'Infant Mortality Rate',
#        'Log Literacy', 'Log Health Expenditure', 'Log Pollution',
#        'Log Life Exp', 'Log GDP', 'Log Infant Mortality', 'Log_GDP',
#        'Log_Health_Expenditure', 'Log_Pollution'],
#       dtype='object')

# %%
X = sm.add_constant(data['Log_GDP'])
Y = data['Life_Expectancy']

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     22.16
# Date:                Thu, 09 May 2024   Prob (F-statistic):           2.57e-06
# Time:                        10:29:30   Log-Likelihood:                -20836.
# No. Observations:                5851   AIC:                         4.168e+04
# Df Residuals:                    5849   BIC:                         4.169e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         73.9696      0.817     90.491      0.000      72.367      75.572
# ...

# %%
X = sm.add_constant(data['Log_GDP'])
Y = data['Log_Health_Expenditure']

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Log_Health_Expenditure   R-squared:                       0.004
# Model:                                OLS   Adj. R-squared:                  0.004
# Method:                     Least Squares   F-statistic:                     24.60
# Date:                    Thu, 09 May 2024   Prob (F-statistic):           7.24e-07
# Time:                            10:24:31   Log-Likelihood:                -11427.
# No. Observations:                    5851   AIC:                         2.286e+04
# Df Residuals:                        5849   BIC:                         2.287e+04
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.4542      0.164     39.425      0.000       6.133       6.775
# ...

# %%
X = sm.add_constant(data['Log_GDP'])
Y = data['Infant Mortality Rate']

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Infant Mortality Rate   R-squared:                       0.012
# Model:                               OLS   Adj. R-squared:                  0.012
# Method:                    Least Squares   F-statistic:                     69.17
# Date:                   Thu, 09 May 2024   Prob (F-statistic):           1.11e-16
# Time:                           10:24:10   Log-Likelihood:                -27061.
# No. Observations:                   5851   AIC:                         5.413e+04
# Df Residuals:                       5849   BIC:                         5.414e+04
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.2105      2.369      3.888      0.000       4.567      13.854
# ...

# %%
#from infant_long, select the data for the year 2000 and 2020

infant_2000 = infant_long[infant_long['Year'] == 2000]
infant_2020 = infant_long[infant_long['Year'] == 2020]

# %%
#mean of infant mortality rate for 2000 and 2020

mean_infant_2000 = infant_2000['Infant Mortality Rate'].mean()
mean_infant_2020 = infant_2020['Infant Mortality Rate'].mean()

# %%
#percentage decrease in infant mortality rate from 2000 to 2020

percentage_decrease = ((mean_infant_2000 - mean_infant_2020) / mean_infant_2000) * 100
print("Percentage Decrease of Infant Mortality Rate from 2000 to 2020:")
print(percentage_decrease)
# Out:
# Percentage Decrease of Infant Mortality Rate from 2000 to 2020:
# 46.794154012428656

# %%
#calculate overall percentage increase in GDP from 2000 to 2020 from gdp_lcu_long

gdp_2000 = gdp_lcu_long[gdp_lcu_long['Year'] == 2000]['GDP'].sum()
gdp_2020 = gdp_lcu_long[gdp_lcu_long['Year'] == 2020]['GDP'].sum()

percentage_increase = ((gdp_2020 - gdp_2000) / gdp_2000) * 100
print("Percentage Increase of GDP from 2000 to 2020:")
print(percentage_increase)
# Out:
# Percentage Increase of GDP from 2000 to 2020:
# 1581.9630058828673
